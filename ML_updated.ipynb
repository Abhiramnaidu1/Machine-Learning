# %% [markdown]
# # **Pretrained Encyclopedia: Weakly Supervised Knowledge-Pretrained Language Model**

# %% [markdown]
# **Authors:** Wenhan Xiong, Jingfei Du, William Yang Wang, Veselin Stoyanov

# %% [markdown]
# ## **Import Modules**

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.2.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)

# %%
import transformers

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import tokenizers

# %%
import torch
from transformers import BertForQuestionAnswering

bert_qa_model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
from transformers import BertTokenizer

bert_qa_tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer 
import textwrap
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from difflib import SequenceMatcher

# %%
from transformers import pipeline

# %% [markdown]
# ## **Dataset**

# %%
squad_train_data = pd.read_json('https://raw.githubusercontent.com/Abhiramnaidu1/ML_dataset/main/squad/train-v2.0.json')
squad_test_data = pd.read_json('https://raw.githubusercontent.com/Abhiramnaidu1/ML_dataset/main/squad/dev-v2.0.json')

# %%
squad_train_data.head(1)['data']
# Out:
# 0    {'title': 'Beyoncé', 'paragraphs': [{'qas': [{...
# Name: data, dtype: object

# %%
titles = []
contexts = []
questions = []
ids =[]
answers = []
answer_start = []
titles_test = []
contexts_test = []
questions_test = []
ids_test =[]
answers_test = []
answer_start_test = []
is_impossible = []
is_impossible_test = []
for i in squad_train_data['data']:
  title = i['title']
  for j in i['paragraphs']:
    context = j['context']
    for k in j['qas']:
      question = k['question']
      id_ = k['id']
      is_impossible_ = k['is_impossible']
      for l in k['answers']:
        titles.append(title)
        contexts.append(context)
        questions.append(question)
        ids.append(id_)
        answers.append(l['text'])
        answer_start.append(l['answer_start'])
        is_impossible.append(is_impossible_)

for i in squad_test_data['data']:
  title_test = i['title']
  for j in i['paragraphs']:
    context_test = j['context']
    for k in j['qas']:
      question_test = k['question']
      id_test_ = k['id']
      is_impossible_test_ = k['is_impossible']
      for l in k['answers']:
        titles_test.append(title_test)
        contexts_test.append(context_test)
        questions_test.append(question_test)
        ids_test.append(id_test_)
        answers_test.append(l['text'])
        answer_start_test.append(l['answer_start'])
        is_impossible_test.append(is_impossible_test_)

# %%
'''for i in is_impossible:
  if i == 'True':
    print('h')'''
for i in is_impossible_test:
  if i == 'True':
    print('h')

# %%
train = pd.DataFrame({'title':titles, 'question':questions, 'id':ids, 'answers':answers, 'answer_start':answer_start ,'context':contexts})
test = pd.DataFrame({'title':titles_test, 'question':questions_test, 'id':ids_test, 'answers':answers_test, 'answer_start':answer_start_test ,'context':contexts_test})

# %%
train.head(5)
# Out:
#      title  ...                                            context
# 0  Beyoncé  ...  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1  Beyoncé  ...  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 2  Beyoncé  ...  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 3  Beyoncé  ...  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 4  Beyoncé  ...  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
#
# [5 rows x 6 columns]

# %% [markdown]
# ## **Training Model**

# %% [markdown]
# Taking 100 rows of data due to memory constraits

# %%
train= train.head(100)
MAX_LEN=135

# %%
rec = train.shape[0]  # Number of records in the training set
inputs = np.ones((rec, MAX_LEN), dtype = 'int32') # Input vector
attention_mask = np.zeros((rec, MAX_LEN), dtype = 'int32') # Attention Mask
token_type_ids = np.zeros((rec, MAX_LEN), dtype = 'int32') # Tokens produced
start_tokens = np.zeros((rec, MAX_LEN), dtype = 'int32') # Start logit for answer
end_tokens = np.zeros((rec, MAX_LEN), dtype = 'int32') # End logit for answer

for i in range(rec):

  context = ' '+' '.join(train.loc[i, 'context'].split())
  answer = ' '+' '.join(train.loc[i, 'answers'].split())
  question = ' '+' '.join(train.loc[i, 'question'].split())

  start_idx = train.loc[i, 'answer_start']

  chars = np.zeros((len(context)))
  chars[start_idx:start_idx + len(answer)] = 1
  if context[start_idx - 1] == ' ':
    chars[start_idx - 1] = 1
  
  enc1 = bert_qa_tokenizer.encode(context)
  enc2 = bert_qa_tokenizer.encode(question)
  print(enc1)
  # For resource limitations only.

  if len(enc1) + len(enc2) + 4 < MAX_LEN:

    #creating offsets
    offsets = []
    start_idx = 0

    for t in enc1:
      w = bert_qa_tokenizer.decode([t])
      offsets.append((start_idx, start_idx + len(w)))
      start_idx += len(w)
    
    # Those which are a part of the answer

    tokens = []
    for j, (a, b) in enumerate(offsets):
      sum_ = np.sum(chars[a:b])
      if sum_ > 0:
        tokens.append(j)

    # The input for roberta is in the form <s> Question </s></s> Context </s>
    
    inputs[i, :len(enc1) + len(enc2) + 4] = [0] + enc2 + [2,2] + enc1 + [2]

    attention_mask[i, :len(enc1) + len(enc2) + 4] = 1

    if len(tokens) > 0:
      start_tokens[i, tokens[0] + 1] = 1
      end_tokens[i, tokens[-1] + 1] = 1
# Out:
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 20773, 21025, 19358, 22815, 1011, 5708, 1006, 1013, 12170, 23432, 29715, 3501, 29678, 12325, 29685, 1013, 10506, 1011, 10930, 2078, 1011, 2360, 1007, 1006, 2141, 2244, 1018, 1010, 3261, 1007, 2003, 2019, 2137, 3220, 1010, 6009, 1010, 2501, 3135, 1998, 3883, 1012, 2141, 1998, 2992, 1999, 5395, 1010, 3146, 1010, 2016, 2864, 1999, 2536, 4823, 1998, 5613, 6479, 2004, 1037, 2775, 1010, 1998, 3123, 2000, 4476, 1999, 1996, 2397, 4134, 2004, 2599, 3220, 1997, 1054, 1004, 1038, 2611, 1011, 2177, 10461, 1005, 1055, 2775, 1012, 3266, 2011, 2014, 2269, 1010, 25436, 22815, 1010, 1996, 2177, 2150, 2028, 1997, 1996, 2088, 1005, 1055, 2190, 1011, 4855, 2611, 2967, 1997, 2035, 2051, 1012, 2037, 14221, 2387, 1996, 2713, 1997, 20773, 1005, 1055, 2834, 2201, 1010, 20754, 1999, 2293, 1006, 2494, 1007, 1010, 2029, 2511, 2014, 2004, 1037, 3948, 3063, 4969, 1010, 3687, 2274, 8922, 2982, 1998, 2956, 1996, 4908, 2980, 2531, 2193, 1011, 2028, 3895, 1000, 4689, 1999, 2293, 1000, 1998, 1000, 3336, 2879, 1000, 1012, 102]
# [101, 2206, 1996, 4487, 19022, 5685, 3672, 1997, 10461, 1005, 1055, 2775, 1999, 2238, 2384, 1010, 2016, 2207, 2014, 2117, 3948, 2201, 1010, 1038, 1005, 2154, 1006, 2294, 1007, 1010, 2029, 4838, 4978, 1000, 2139, 3900, 24728, 1000, 1010, 1000, 20868, 2890, 24759, 10732, 3085, 1000, 1010, 1998, 1000, 3376, 16374, 1000, 1012, 20773, 2036, 20510, 2046, 3772, 1010, 2007, 1037, 3585, 7595, 1011, 4222, 2
# [101, 1996, 3588, 2316, 2372, 2680, 1000, 2981, 2308, 2112, 1045, 1000, 1010, 2029, 2596, 2006, 1996, 6050, 2000, 1996, 2456, 2143, 1010, 4918, 1005, 1055, 7048, 1012, 2009, 2150, 2037, 2190, 1011, 17918, 2309, 1010, 22286, 1996, 1057, 1012, 1055, 1012, 4908, 2980, 2531, 3673, 2005, 5408, 5486, 3134, 1012, 1999, 2220, 2541, 1010, 2096, 10461, 1005, 1055, 2775, 2001, 7678, 2037, 2353, 2201, 1010, 20773, 5565, 1037, 2350, 2535, 1999, 1996, 8692, 2081, 1011, 2005, 1011, 2547, 2143, 1010, 11425, 1024, 1037, 5099, 3246, 2527, 1010, 4626, 4077, 2137, 3364, 2033, 10023, 2072, 13569, 7512, 1012, 2275, 1999, 4407, 1010, 1996, 2143, 2003, 1037, 2715, 7613, 1997, 1996, 3708, 2301, 3850, 11425, 2011, 2413, 4543, 10870, 12170, 4371, 2102, 1012, 2043, 1996, 2353, 2201, 12084, 2001, 2207, 1999, 2089, 2541, 1010, 6735, 6582, 1998, 11111, 17753, 6406, 1037, 9870, 6815, 2008, 1996, 2774, 2020, 6461, 2012, 2068, 1012, 1996, 2201, 6006, 2012, 2193, 2028, 2006, 1996, 1057, 1012, 1055, 1012, 4908, 3263, 1010, 2007, 2034, 1011, 2733, 4341, 1997, 5764, 2509, 1010, 2199, 4809, 2853, 1012, 1996, 2201, 18379, 2060, 2193, 1011, 2028, 4978, 1010, 1000, 9573, 8516, 27113, 2271, 1000, 1998, 1996, 2516, 2650, 1010, 1000, 12084, 1000, 1010, 1996, 3732, 1997, 2029, 3687, 1996, 2177, 1037, 8922, 2400, 2005, 2190, 1054, 1004, 1038, 2836, 2011, 1037, 6829, 2030, 2177, 2007, 2955, 1012, 2044, 8287, 2037, 6209, 2201, 1022, 2420, 1997, 4234, 1999, 2255, 2541, 1010, 1996, 2177, 2623, 1037, 14221, 2000, 2582, 7323, 3948, 10922, 1012, 102]

# %%
def build_model():
  ids = tf.keras.layers.Input((MAX_LEN,), dtype = tf.int32)
  att = tf.keras.layers.Input((MAX_LEN,), dtype = tf.int32)
  tok = tf.keras.layers.Input((MAX_LEN,), dtype = tf.int32)
  print(att)

  
  # x=DistlBert_model

  
  
  bert_model = bert_qa_model
 
  x = bert_model(ids, attention_mask=att, token_type_ids = tok)
  print(att)
  # For start logit

  x1 = tf.keras.layers.Dropout(0.1)(x[0])
  x1 = tf.keras.layers.Conv1D(1,1)(x1)
  x1 = tf.keras.layers.Flatten()(x1)
  x1 = tf.keras.layers.Activation('softmax')(x1)
  
  # For end logit

  x2 = tf.keras.layers.Dropout(0.1)(x[0]) 
  x2 = tf.keras.layers.Conv1D(1,1)(x2)
  x2 = tf.keras.layers.Flatten()(x2)
  x2 = tf.keras.layers.Activation('softmax')(x2)

  # Initalising the model

  model = tf.keras.models.Model(inputs = [ids, att, tok], outputs = [x1, x2])
  optimizer = tf.keras.optimizers.Adam(learning_rate = 3e-5)
  model.compile(loss='categorical_crossentropy', optimizer = optimizer)

  return model

# %% [markdown]
# ## **Model Evaluation**

# %%
test = test.drop_duplicates( subset=None, keep="first", inplace=False)

# %% [markdown]
# ### **BERT Question answering model finetuned with SQuaD dataset**

# %%
def bert_qa_answer_question(question, answer_text):
    
    # Apply the tokenizer and segment input text of question and context pair.
    input_ids = bert_qa_tokenizer.encode(question, answer_text)
    sep_index = input_ids.index(bert_qa_tokenizer.sep_token_id)
    num_seg_a = sep_index + 1
    num_seg_b = len(input_ids) - num_seg_a

    # Construct the list of 0s and 1s.
    segment_ids = [0]*num_seg_a + [1]*num_seg_b
    assert len(segment_ids) == len(input_ids)
    outputs = bert_qa_model(torch.tensor([input_ids]), 
                    token_type_ids=torch.tensor([segment_ids]), 
                    return_dict=True) 

    start_scores = outputs.start_logits
    end_scores = outputs.end_logits

    # Find the tokens with the highest `start` and `end` scores.
    answer_start = torch.argmax(start_scores)
    answer_end = torch.argmax(end_scores)

    # Get the string versions of the input tokens.
    tokens = bert_qa_tokenizer.convert_ids_to_tokens(input_ids)
    answer = tokens[answer_start]

    # Select the remaining answer tokens and join them with whitespace.
    for i in range(answer_start + 1, answer_end + 1):
        if tokens[i][0:2] == '##':
            answer += tokens[i][2:]
        else:
            answer += ' ' + tokens[i]

    print('Answer: "' + answer + '"')
    return answer

# %% [markdown]
# #### Model Verification

# %%
# Wrap text to 80 characters.
wrapper = textwrap.TextWrapper(width=80) 

bert_abstract = "We introduce a new language representation model called BERT, which stands for Bidirectional Encoder Representations from Transformers. Unlike recent language representation models (Peters et al., 2018a; Radford et al., 2018), BERT is designed to pretrain deep bidirectional representations from unlabeled text by jointly conditioning on both left and right context in all layers. As a result, the pre-trained BERT model can be finetuned with just one additional output layer to create state-of-the-art models for a wide range of tasks, such as question answering and language inference, without substantial taskspecific architecture modifications. BERT is conceptually simple and empirically powerful. It obtains new state-of-the-art results on eleven natural language processing tasks, including pushing the GLUE score to 80.5% (7.7% point absolute improvement), MultiNLI accuracy to 86.7% (4.6% absolute improvement), SQuAD v1.1 question answering Test F1 to 93.2 (1.5 point absolute improvement) and SQuAD v2.0 Test F1 to 83.1 (5.1 point absolute improvement)."

print(wrapper.fill(bert_abstract))
# Out:
# We introduce a new language representation model called BERT, which stands for
# Bidirectional Encoder Representations from Transformers. Unlike recent language
# representation models (Peters et al., 2018a; Radford et al., 2018), BERT is
# designed to pretrain deep bidirectional representations from unlabeled text by
# jointly conditioning on both left and right context in all layers. As a result,
# the pre-trained BERT model can be finetuned with just one additional output
# layer to create state-of-the-art models for a wide range of tasks, such as
# question answering and language inference, without substantial taskspecific
# architecture modifications. BERT is conceptually simple and empirically
# powerful. It obtains new state-of-the-art results on eleven natural language
# processing tasks, including pushing the GLUE score to 80.5% (7.7% point absolute
# improvement), MultiNLI accuracy to 86.7% (4.6% absolute improvement), SQuAD v1.1
# question answering Test F1 to 93.2 (1.5 point absolute improvement) and SQuAD
# v2.0 Test F1 to 83.1 (5.1 point absolute improvement).

# %%
question = "What are some example applications of BERT?"

bert_qa_answer_question(question, bert_abstract)
# Out:
# Answer: "question answering and language inference"
# 'question answering and language inference'

# %%
question = "What does the 'B' in BERT stand for?"

bert_qa_answer_question(question, bert_abstract)
# Out:
# Answer: "bidirectional encoder representations from transformers"
# 'bidirectional encoder representations from transformers'

# %% [markdown]
# ### **Distilled BERT base model finetuned with SQuaD dataset**

# %%
nlp_qa = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)

# %%
def distil_bert_answer_model(question,context):
  return nlp_qa(question,context)['answer']

# %% [markdown]
# #### Model Verification

# %%
question = "What does the 'B' in BERT stand for?"
distil_bert_answer_model(question,bert_abstract)
# Out:
# 'Bidirectional Encoder Representations from Transformers'

# %%
question = "What are some example applications of BERT?"
nlp_qa(question,bert_abstract)['answer']
# Out:
# 'question answering and language inference'

# %% [markdown]
# ## **Evaluation**

# %%
test
# Out:
#          title  ...                                            context
# 0      Normans  ...  The Normans (Norman: Nourmands; French: Norman...
# 4      Normans  ...  The Normans (Norman: Nourmands; French: Norman...
# 5      Normans  ...  The Normans (Norman: Nourmands; French: Norman...
# 8      Normans  ...  The Normans (Norman: Nourmands; French: Norman...
# 12     Normans  ...  The Normans (Norman: Nourmands; French: Norman...
# ...        ...  ...                                                ...
# 20287    Force  ...  The pound-force has a metric counterpart, less...
# 20288    Force  ...  The pound-force has a metric counterpart, less...
# 20291    Force  ...  The pound-force has a metric counterpart, less...
# 20292    Force  ...  The pound-force has a metric counterpart, less...
# 20297    Force  ...  The pound-force has a metric counterpart, less...
#
# [10388 rows x 6 columns]

# %%
test=test.head(500)

# %% [markdown]
# ### **AnswerPrediction using BERT Question Answering Model**

# %%
test['predicted_answer_bert_qa'] = test.apply(lambda x:bert_qa_answer_question(x.question,x.context),axis=1)
# Out:
# Answer: "france"
# Answer: "10th and 11th centuries"
# Answer: "10th and 11th centuries"
# Answer: "denmark , iceland and norway"
# Answer: "rollo"
# Answer: "10th"
# Answer: "10th"
# Answer: "10th"
# Answer: "william the conqueror"
# Answer: "richard i of normandy"
# Answer: "christian"
# Answer: "christian"
# Answer: "norseman , viking"
# Answer: "norseman , viking"
# Answer: "9th century"
# Answer: "911"
# Answer: "king charles iii of west francia"
# Answer: "river seine"
# Answer: "river seine"
# Answer: "rollo"
# Answer: "norse religion and old norse language with catholicism ( christianity"
# Answer: "north"
# Answer: "north"
# Answer: "fighting horsemen"
# Answer: "the pechenegs , the bulgars , and especially the seljuk turks"
# Answer: "the pechenegs , the bulgars , and especially the seljuk turks"
# Answer: "the pechenegs , the bulgars , and especially the seljuk turks"
# Answer: "1050s"
# Answer: "1050s"
# Answer: "1060s"
# Answer: "1060s"
# Answer: "alexius komnenos"
# Answer: "afranji"
# Answer: "oursel"
# Answer: "turkish forces"
# Answer: "italo - norman named raoul"
# Answer: "italo - norman named raoul"
# Answer: "italo - norman named raoul"
# Answer: "robert guiscard"
# Answer: "1085"
# Answer: "1085"
# Answer: "30 , 000"
# Answer: "deabolis"
# Answer: "deabolis"
# Answer: "bohemond"
# Answer: "river deabolis"
# Answer: "river deabolis"
# Answer: "1185"
# Answer: "1185"
# Answer: "dyrrachium"
# Answer: "dyrrachium"
# Answer: "the adriatic"
# Answer: "the adriatic"
# Answer: "king ethelred ii of england"
# Answer: "king ethelred ii of england"
# Answer: "duke richard ii of normandy"
# Answer: "normandy"
# Answer: "sweyn forkbeard"
# Answer: "harthacnut"
# Answer: "1041"
# Answer: "1041"
# Answer: "robert of jumieges"
# Answer: "battle of hastings"
# Answer: "battle of hastings"
# Answer: "battle of hastings"
# Answer: "duke william ii of normandy"
# Answer: "duke william ii of normandy"
# Answer: "1066"
# Answer: "1066"
# Answer: "anglo - saxons"
# Answer: "anglo - saxons"
# Answer: "old english"
# Answer: "1169"
# Answer: "irish"
# Answer: "irish culture"
# Answer: "irish culture"
# Answer: "king malcolm iii"
# Answer: "king malcolm iii"
# Answer: "king malcolm iii"
# Answer: "king malcolm iii"
# Answer: "king malcolm iii"
# Answer: "1072"
# Answer: "his son duncan"
# Answer: "sybilla of normandy"
# Answer: "sybilla of normandy"
# Answer: "normans"
# Answer: "hereford"
# Answer: "the welsh"
# Answer: "edward the confessor"
# Answer: "the marches"
# Answer: "1018"
# Answer: "1018"
# Answer: "william of montreuil"
# Answer: "1097"
# Answer: "tancred"
# Answer: "conquest of jerusalem"
# Answer: "380 years"
# Answer: "a storm"
# Answer: "berengaria"
# Answer: "1191"
# Answer: "isaac komnenos"
# Answer: "isaac komnenos"
# Answer: "conrad of montferrat"
# Answer: "silver"
# Answer: "guy de lusignan"
# Answer: "guy de lusignan"
# Answer: "africa"
# Answer: "bethencourt"
# Answer: "enrique perez de guzman , 2nd count de niebla"
# Answer: "maciot de bethencourt"
# Answer: "channel islands"
# Answer: "channel islands"
# Answer: "two"
# Answer: "romanesque"
# Answer: "rounded arches"
# Answer: "early gothic"
# Answer: "anglo - saxon"
# Answer: "kingdom of sicily"
# Answer: "kingdom of sicily"
# Answer: "early 11th century"
# Answer: "early 11th century"
# Answer: "early 11th century"
# Answer: "the dukes"
# Answer: "the dukes"
# Answer: "the dukes"
# Answer: "16th century"
# Answer: "16th century"
# Answer: "16th century"
# Answer: "embroidery"
# Answer: "bayeux tapestry"
# Answer: "bayeux tapestry"
# Answer: "odo"
# Answer: "mosaics"
# Answer: "11th"
# Answer: "11th"
# Answer: "william of volpiano and john of ravenna"
# Answer: "southern italy"
# Answer: "sant ' eufemia"
# Answer: "sant ' eufemia"
# Answer: "sant ' eufemia"
# Answer: "robert guiscard"
# Answer: "singing"
# Answer: "singing"
# Answer: "computational complexity theory"
# Answer: "inherent difficulty"
# Answer: "inherent difficulty"
# Answer: "computational problem"
# Answer: "computational problem"
# Answer: "computational problem"
# Answer: "significant resources"
# Answer: "significant resources"
# Answer: "mathematical models of computation"
# Answer: "time and storage"
# Answer: "the number of gates"
# Answer: "the number of gates"
# Answer: "limits on what computers can and cannot do"
# Answer: "limits on what computers can and cannot do"
# Answer: "analysis of algorithms and computability theory"
# Answer: "computational complexity theory"
# Answer: "computational complexity theory"
# Answer: "computational complexity theory"
# Answer: "theoretical computer science are analysis of algorithms and computability theory . a key distinction between analysis of algorithms and computational complexity theory"
# Answer: "theoretical computer science are analysis of algorithms and computability theory . a key distinction between analysis of algorithms and computational complexity theory"
# Answer: "a problem instance"
# Answer: "a problem instance"
# Answer: "a problem"
# Answer: "a problem"
# Answer: "a problem"
# Answer: "concrete"
# Answer: "concrete"
# Answer: "the instance"
# Answer: "the instance"
# Answer: "the instance"
# Answer: "solution"
# Answer: "solution"
# Answer: "solution"
# Answer: "2000"
# Answer: "asking for a round trip through all sites in milan"
# Answer: "asking for a round trip through all sites in milan"
# Answer: "asking for a round trip through all sites in milan"
# Answer: "computational problems"
# Answer: "problem instance"
# Answer: "problem instance"
# Answer: "binary alphabet"
# Answer: "binary alphabet"
# Answer: "bitstrings"
# Answer: "binary notation"
# Answer: "directly via their adjacency matrices"
# Answer: "directly via their adjacency matrices"
# Answer: "decision problems"
# Answer: "decision problems"
# Answer: "yes or no"
# Answer: "1 or 0"
# Answer: "yes"
# Answer: "yes"
# Answer: "yes"
# Answer: "yes"
# Answer: "arbitrary"
# Answer: "arbitrary"
# Answer: "the formal language"
# Answer: "the formal language"
# Answer: "the formal language"
# Answer: "binary strings"
# Answer: "computational problem"
# Answer: "single"
# Answer: "single"
# Answer: "function problem"
# Answer: "function problem"
# Answer: "function problem"
# Answer: "the integer factorization problem"
# Answer: "the integer factorization problem"
# Answer: "the integer factorization problem"
# Answer: "complex"
# Answer: "as decision problems"
# Answer: "as decision problems"
# Answer: "triples ( a , b , c )"
# Answer: "triples ( a , b , c )"
# Answer: "triples ( a , b , c )"
# Answer: "the size of the input in bits"
# Answer: "the size of the input in bits"
# Answer: "the instance"
# Answer: "the instance"
# Answer: "as a function of the size of the instance"
# Answer: "as a function of the size of the instance"
# Answer: "bits"
# Answer: "input size"
# Answer: "input size"
# Answer: "cobham"
# Answer: "cobham"
# Answer: "cobham"
# Answer: "time taken"
# Answer: "t ( n )"
# Answer: "t ( n )"
# Answer: "the maximum time taken over all inputs of size n"
# Answer: "polynomial time"
# Answer: "polynomial time"
# Answer: "turing machine"
# Answer: "turing machine"
# Answer: "an algorithm"
# Answer: "turing machine"
# Answer: "turing machine"
# Answer: "symbols"
# Answer: "deterministic turing machine"
# Answer: "deterministic turing machine"
# Answer: "deterministic turing machine"
# Answer: "rules to determine its future actions"
# Answer: "rules to determine its future actions"
# Answer: "probabilistic turing machine"
# Answer: "probabilistic turing machine"
# Answer: "probabilistic turing machine"
# Answer: "non - deterministic turing machine"
# Answer: "non - deterministic turing machine"
# Answer: "non - deterministic turing machine"
# Answer: "randomized algorithms"
# Answer: "complexity classes"
# Answer: "resources ( such as time or space ) are bounded"
# Answer: "deterministic turing machines , probabilistic turing machines , non - deterministic turing machines , quantum turing machines , symmetric turing machines and alternating turing machines"
# Answer: "random access machines"
# Answer: "computational power"
# Answer: "time and memory"
# Answer: "time and memory"
# Answer: "the machines operate deterministically"
# Answer: "the machines operate deterministically"
# Answer: "non - deterministic"
# Answer: "non - deterministic"
# Answer: "more unusual resources"
# Answer: "more unusual resources"
# Answer: "mathematical models"
# Answer: "mathematical models"
# Answer: "non - deterministic time"
# Answer: "non - deterministic time"
# Answer: "" yes " or " no ""
# Answer: "" yes " or " no ""
# Answer: "" yes " or " no ""
# Answer: "difficulty"
# Answer: "dtime ( f ( n ) )"
# Answer: "dtime ( f ( n ) )"
# Answer: "time and space"
# Answer: "time and space"
# Answer: "complexity"
# Answer: "complexity"
# Answer: "computational"
# Answer: "computational"
# Answer: "blum complexity axioms"
# Answer: "blum complexity axioms"
# Answer: "complexity measures"
# Answer: "complexity measures"
# Answer: "complexity measures"
# Answer: "complexity"
# Answer: "complexity"
# Answer: "complexity"
# Answer: "best , worst and average"
# Answer: "best , worst and average"
# Answer: "best , worst and average"
# Answer: "time complexity"
# Answer: "time complexity"
# Answer: "time complexity"
# Answer: "time complexity"
# Answer: "inputs"
# Answer: "quicksort"
# Answer: "quicksort"
# Answer: "quicksort"
# Answer: "worst - case"
# Answer: "worst - case"
# Answer: "o ( n2 )"
# Answer: "the most efficient algorithm"
# Answer: "the most efficient algorithm"
# Answer: "analysis of algorithms"
# Answer: "lower bounds"
# Answer: "lower bounds"
# Answer: "lower bounds"
# Answer: "upper bound"
# Answer: "upper bound"
# Answer: "all possible algorithms"
# Answer: "all possible algorithms"
# Answer: "big o notation"
# Answer: "constant factors and smaller terms"
# Answer: "o ( n2 )"
# Answer: "computational model used"
# Answer: "computational model used"
# Answer: "computational model used"
# Answer: "complexity classes"
# Answer: "complexity classes"
# Answer: "definitions"
# Answer: "complicated definitions"
# Answer: "complicated definitions"
# Answer: "the chosen machine model"
# Answer: "the chosen machine model"
# Answer: "linear time"
# Answer: "linear time"
# Answer: "single - tape turing machines"
# Answer: "single - tape turing machines"
# Answer: "cobham - edmonds"
# Answer: "cobham - edmonds"
# Answer: "complexity class p"
# Answer: "complexity class p"
# Answer: "time or space"
# Answer: "bounding"
# Answer: "complexity classes"
# Answer: "bpp , zpp and rp"
# Answer: "boolean"
# Answer: "boolean"
# Answer: "quantum"
# Answer: "# p"
# Answer: "interactive"
# Answer: "computation time"
# Answer: "dtime ( n2 )"
# Answer: "time and space hierarchy theorems"
# Answer: "a proper hierarchy"
# Answer: "a proper hierarchy"
# Answer: "a proper hierarchy"
# Answer: "quantitative"
# Answer: "quantitative"
# Answer: "the time and space hierarchy theorems"
# Answer: "the time and space hierarchy theorems"
# Answer: "exptime"
# Answer: "pspace"
# Answer: "reduction"
# Answer: "reduction"
# Answer: "another problem"
# Answer: "no more difficult"
# Answer: "no more difficult"
# Answer: "cook reductions , karp reductions and levin reductions"
# Answer: "cook reductions , karp reductions and levin reductions"
# Answer: "bound on the complexity of reductions"
# Answer: "bound on the complexity of reductions"
# Answer: "polynomial - time reduction"
# Answer: "polynomial - time reduction"
# Answer: "multiplying two integers"
# Answer: "polynomial time"
# Answer: "polynomial time"
# Answer: "input"
# Answer: "the problem of multiplying two integers"
# Answer: "the problem of multiplying two integers"
# Answer: "the type of reduction being used"
# Answer: "an"
# Answer: "an"
# Answer: "solve any problem in c"
# Answer: "np - hard problems"
# Answer: "np - hard problems"
# Answer: "np - complete problems"
# Answer: "p"
# Answer: "p"
# Answer: "there is no known polynomial - time solution"
# Answer: "there is no known polynomial - time solution"
# Answer: "np"
# Answer: "np"
# Answer: "p"
# Answer: "cobham – edmonds thesis"
# Answer: "np"
# Answer: "boolean satisfiability problem"
# Answer: "deterministic turing machines"
# Answer: "deterministic turing machines"
# Answer: "more efficient solutions"
# Answer: "more efficient solutions"
# Answer: "more efficient solutions"
# Answer: "protein structure prediction"
# Answer: "us $ 1 , 000 , 000"
# Answer: "us $ 1 , 000 , 000"
# Answer: "ladner"
# Answer: "the graph isomorphism problem"
# Answer: "the graph isomorphism problem"
# Answer: "the integer factorization problem"
# Answer: "the integer factorization problem"
# Answer: "the integer factorization problem"
# Answer: "graph isomorphism problem"
# Answer: "graph isomorphism problem"
# Answer: "np - complete"
# Answer: "np - complete"
# Answer: "polynomial time hierarchy collapses to its second level . since it is widely believed that the polynomial hierarchy"
# Answer: "polynomial time hierarchy collapses to its second level . since it is widely believed that the polynomial hierarchy"
# Answer: "second level"
# Answer: "second level"
# Answer: "laszlo babai and eugene luks"
# Answer: "laszlo babai and eugene luks"
# Answer: "integer factorization problem"
# Answer: "integer factorization problem"
# Answer: "integer factorization problem"
# Answer: "k"
# Answer: "rsa algorithm"
# Answer: "rsa algorithm"
# Answer: "general number field sieve"
# Answer: "general number field sieve"
# Answer: "general number field sieve"
# Answer: "unequal"
# Answer: "unequal"
# Answer: "unequal"
# Answer: "p = pspace"
# Answer: "it"
# Answer: "proving that any of these classes are unequal"
# Answer: "co - np"
# Answer: "reversed"
# Answer: "np is not equal to co - np ; however , it has not yet been proven . it has been shown that if these two complexity classes are not equal then p is not equal to np"
# Answer: "np is not equal to co - np ; however , it has not yet been proven . it has been shown that if these two complexity classes are not equal then p is not equal to np"
# Answer: "p is not equal to np"
# Answer: "p is not equal to np"
# Answer: "l"
# Answer: "complexity"
# Answer: "complexity"
# Answer: "complexity classes"
# Answer: "complexity classes"
# Answer: "nl and nc"
# Answer: "it is not known if they are distinct or equal classes"
# Answer: "intractable problems"
# Answer: "intractable problems"
# Answer: "polynomial time"
# Answer: "polynomial time"
# Answer: "np - complete"
# Answer: "np - complete"
# Answer: "presburger arithmetic"
# Answer: "presburger arithmetic"
# Answer: "algorithms"
# Answer: "algorithms"
# Answer: "np - complete knapsack problem"
# Answer: "np - complete knapsack problem"
# Answer: "np - complete knapsack problem"
# Answer: "less than quadratic time"
# Answer: "less than quadratic time"
# Answer: "np - complete boolean satisfiability problem"
# Answer: "np - complete boolean satisfiability problem"
# Answer: "np - complete boolean satisfiability problem"
# Answer: "turing machines"
# Answer: "turing machines"
# Answer: "turing machines"
# Answer: "alan turing"
# Answer: "turing machines"
# Answer: "1936"
# Answer: "a computer"
# Answer: "" on the computational complexity of algorithms"
# Answer: "" on the computational complexity of algorithms"
# Answer: "juris hartmanis and richard stearns"
# Answer: "1965"
# Answer: "time and space complexity"
# Answer: "time and space complexity"
# Answer: "time and space complexity"
# Answer: "1965"
# Answer: "1965"
# Answer: "john myhill"
# Answer: "1961"
# Answer: "hisao yamada"
# Answer: "input encoding"
# Answer: "encoding"
# Answer: "encoding"
# Answer: "manuel blum"
# Answer: "speed - up theorem"
# Answer: "" reducibility among combinatorial problems"
# Answer: "" reducibility among combinatorial problems"
# Answer: "21"
# Answer: "socal"
# Answer: "10"
# Answer: "10"
# Answer: "economic center"
# Answer: "economic center"
# Answer: "demographics and economic"
# Answer: "demographics and economic"
# Answer: "demographics and economic"
# Answer: "historical political divisions"
# Answer: "greater southern california megaregion"
# Answer: "greater southern california megaregion"
# Answer: "11"
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### **AnswerPrediction using Distilled BERT Model**

# %%
test['predicted_answer_distil_bert_qa'] = test.apply(lambda x:distil_bert_answer_model(x.question,x.context),axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## **Metrics**

# %% [markdown]
# ### **Test Normalization**

# %%
stop_words = stopwords.words('english')
ps=PorterStemmer()

# %%
def normalize_text(answer):

  def split_answer(answer):
    return answer.split(' ')
  
  def answer_wo_stopwords(answer):
    stop_words = stopwords.words('english')
    stop_word_list=[]
    for i in answer:
      if i not in stop_words:
        stop_word_list.append(i)
    return stop_word_list
      

  def root_answer(answer):
    ps=PorterStemmer()
    stem_list=[]
    for i in answer:
      stem_word= ps.stem(i)
      stem_list.append(stem_word)
    return stem_list
  
  def lower_answer(answer):
    new_answer = ''.join(answer)
    low_answer = new_answer.lower()
    return low_answer
      
  splitted_answer= split_answer(answer)
  stopwords_no_answer =answer_wo_stopwords(splitted_answer)
  rootwords_answer = root_answer(stopwords_no_answer)
  norm_answer = lower_answer(rootwords_answer)
  
  return norm_answer

# %%
normalize_text("in the late 1990s")
# Out:
# 'late1990'

# %% [markdown]
# ### **EM score**

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def Exact_Match(word1,word2):
  norm_word1=normalize_text(word1)
  norm_word2=normalize_text(word2)
  EM_score = similar(norm_word1,norm_word2)
  return EM_score

# %%
test['EM_score_bert_qa'] = test.apply(lambda x:Exact_Match(x.answers,x.predicted_answer_bert_qa),axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test['EM_score_distil_bert_qa'] = test.apply(lambda x:Exact_Match(x.answers,x.predicted_answer_distil_bert_qa),axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### **F1 Measure**

# %%
binarizer = MultiLabelBinarizer()

def f1_score_model(y_true,y_pred):
  binarizer.fit(y_true)

  f1_score_value=f1_score(binarizer.transform(y_true), binarizer.transform(y_pred), average='macro')
  return f1_score_value

# %% [markdown]
# ## **Summary**

# %% [markdown]
# **EM Score**

# %%
EM_score_bert_qa = test['EM_score_bert_qa'].mean()
EM_score_distil_bert_qa= test['EM_score_distil_bert_qa'].mean()
print('Exact Match score for Bert Question answering model is %f',EM_score_bert_qa)
print('Exact Match score for Distiled Bert Pipeling model is %f',EM_score_distil_bert_qa)
# Out:
# Exact Match score for Bert Question answering model is %f 0.8325303277597107
# Exact Match score for Distiled Bert Pipeling model is %f 0.7965695690122543

# %% [markdown]
# **F1 Measure**

# %%
F1_bert_qa = f1_score_model(test['answers'],test['predicted_answer_bert_qa'])
F1_distilbert_qa = f1_score_model(test['answers'],test['predicted_answer_distil_bert_qa'])
print('F1 score for Bert Question answering model is %f',F1_bert_qa)
print('F1 score for Distiled Bert Pipeling model is %f',F1_distilbert_qa)
# Out:
# F1 score for Bert Question answering model is %f 0.48674160330673
# F1 score for Distiled Bert Pipeling model is %f 0.7696055688465991
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:876: UserWarning: unknown class(es) ['Π'] will be ignored
#   "unknown class(es) {0} will be ignored".format(sorted(unknown, key=str))

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# ## **References**

# %% [markdown]
# 1.	PRETRAINED ENCYCLOPEDIA: WEAKLY SUPERVISED KNOWLEDGE-PRETRAINED LANGUAGE MODEL Wenhan Xiong, Jingfei Du, William Yang Wang, Veselin Stoyanov
# 2.	BERT — transformers 4.12.5 documentation (huggingface.co)
# 3.	[1905.07129] ERNIE: Enhanced Language Representation with Informative Entities (arxiv.org)
# 4.	https://arxiv.org/abs/1903.06164
# 5.	https://arxiv.org/abs/1406.3676
# 6.	https://arxiv.org/pdf/1704.05179.pdf
# 7.	bdhingra/quasar: Datasets for Question Answering by Search and Reading (github.com)
# 8.	nyu-dl/dl4ir-searchQA (github.com)
# 9.	https://drive.google.com/drive/u/2/folders/1kBkQGooNyG0h8waaOJpgdGtOnlb1S649
# 10.	https://github.com/thunlp/ERNIE
# 11.	Pretrained Encyclopedia: Weakly Supervised Knowledge-Pretrained Language Model | Papers With Code
# 12.	nyu-dl/dl4ir-searchQA (github.com)
# 13.	BERT base vs BERT large (opengenus.org)
# 14. https://paperswithcode.com/method/distillbert
# 15. https://arxiv.org/abs/1910.01108
# 16. https://medium.com/huggingface/distilbert-8cf3380435b5
# 17. https://awsdocs-neuron.readthedocs-hosted.com/en/latest/src/examples/tensorflow/huggingface_bert/huggingface_bert.html
# 18. https://huggingface.co/transformers/master/main_classes/pipelines.html
# 19. https://medium.com/analytics-vidhya/hugging-face-transformers-how-to-use-pipelines-10775aa3db7e
# 20. https://medium.com/microsoftazure/accelerate-your-nlp-pipelines-using-hugging-face-transformers-and-onnx-runtime-2443578f4333
# 21. https://theaidigest.in/zero-shot-classification-using-huggingface-transformers-pipeline/
# 22. https://stackoverflow.com/questions/64685243/getting-sentence-embedding-from-huggingface-feature-extraction-pipeline
# 23. https://www.holisticseo.digital/python-seo/nltk/lemmatize#:~:text=How%20to%20use%20NLTK%20Lemmatizaters%20with%20Part%20of,%E2%80%9CJ%E2%80%9D%2C%20%E2%80%9CV%E2%80%9D%20with%20%E2%80%9Cstartswith%E2%80%9D%20method.%20More%20items...%20
# 24. https://www.geeksforgeeks.org/python-lemmatization-with-nltk/
# 25. https://www.guru99.com/stemming-lemmatization-python-nltk.html
# 26. https://textminingonline.com/dive-into-nltk-part-iv-stemming-and-lemmatization
# 27. https://qa.fastforwardlabs.com/no%20answer/null%20threshold/bert/distilbert/exact%20match/f1/robust%20predictions/2020/06/09/Evaluating_BERT_on_SQuAD.html
# 28. https://docs.allennlp.org/models/main/models/rc/metrics/squad_em_and_f1/
# 29. https://stackoverflow.com/questions/52229059/em-score-in-squad-challenge
# 30. https://deepai.org/machine-learning-glossary-and-terms/f-score
# 31. https://vidyasheela.com/what-is-f1-score-and-what-is-its-importance-in-machine-learning/
# 32. https://www.myaccountingcourse.com/accounting-dictionary/f1-score
